# %%
import torch
import torch.nn.functional as F

# %%
x = torch.tensor([10000.0, 5000.0])
print(F.softmax(x/1000, dim=-1))
F.softmax((x - max(x))/1000, dim=-1)
# Out:
# tensor([0.9933, 0.0067])
# tensor([0.9933, 0.0067])
